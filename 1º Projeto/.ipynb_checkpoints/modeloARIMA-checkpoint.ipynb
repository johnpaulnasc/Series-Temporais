# %% [markdown]
# ### `Séries Temporais`

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error as mae

# %%
# elimina os warnings das bibliotecas
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Electric_Production.csv')
df.head()
# Out:
#        DATE  IPG2211A2N
# 0  1/1/1985     72.5052
# 1  2/1/1985     70.6720
# 2  3/1/1985     62.4502
# 3  4/1/1985     57.4714
# 4  5/1/1985     55.3151

# %%
df.DATE = pd.to_datetime(df.DATE)
df.dtypes
# Out:
# DATE          datetime64[ns]
# IPG2211A2N           float64
# dtype: object

# %%
df.set_index('DATE',inplace=True)
df.index = pd.DatetimeIndex(df.index).to_period('D')
df
# Out:
#             IPG2211A2N
# DATE
# 1985-01-01     72.5052
# 1985-02-01     70.6720
# 1985-03-01     62.4502
# 1985-04-01     57.4714
# 1985-05-01     55.3151
# ...                ...
# 2017-09-01     98.6154
# 2017-10-01     93.6137
# 2017-11-01     97.3359
# 2017-12-01    114.7212
# 2018-01-01    129.4048
#
# [397 rows x 1 columns]

# %%
# quantas linhas e colunas?
df.shape
# Out:
# (397, 1)

# %%
# Estatística descritiva
df.describe()
# Out:
#        IPG2211A2N
# count  397.000000
# mean    88.847218
# std     15.387834
# min     55.315100
# 25%     77.105200
# 50%     89.779500
# 75%    100.524400
# max    129.404800

# %%
#Quando começam e terminam os dados?
df.index.min(), df.index.max()
# Out:
# (Period('1985-01-01', 'D'), Period('2018-01-01', 'D'))

# %%
df.columns = ['producao']

# %%
# Vamos dar uma olhada no gráfico de consumo x anos
df['producao'].plot(figsize=(10,6))
# Out:
# <AxesSubplot: xlabel='DATE'>

# %% [markdown]
#  #### `Análise de Sazonalidade`
#
# quando os fenômenos que ocorrem durante o tempo se repetem a cada período idêntico de tempo

# %%
df.diff().plot(figsize=(12,6))
# Out:
# <AxesSubplot: xlabel='DATE'>

# %%
filtro = (df.index.year >= 2010) & (df.index.year >= 2015)
df[filtro].diff().plot(figsize=(15,6))
# Out:
# <AxesSubplot: xlabel='DATE'>

# %% [markdown]
# #### `Análise de Tendência`
#
# é definida como um padrão de crescimento/descrecimento da variável em um certo período de tempo

# %%
df.producao.rolling(12).mean().plot(figsize=(15,6))
# Out:
# <AxesSubplot: xlabel='DATE'>

# %% [markdown]
# #### `Verificando se a série é estacionaria`

# %% [markdown]
# Para que o modelo apresente resultados aceitáveis, é necessário que sejam previamente definidos os parâmetros de cada um dos componentes do modelo ARIMA. Eles dependem do comportamento da série temporal a qual está sendo estudada e, através dela, podem ser determinados com o auxílio do teste de Dickey-Fuller aumentado (ADF) e das funções de autocorrelação (ACF) e autocorrelação parcial

# %% [markdown]
# Para que o ARIMA possa ser aplicado à determinada série temporal, é necessário que seja estacionária. Caso não haja taxa de crescimento significativa, a série pode ser considerada estacionária (e caso haja, deve-se diferenciá-la a fim de atingir um estado de estacionaridade).

# %% [markdown]
# Se o resultado do ADF for menor do que o valor critico para um determinado percentual (5% no nosso caso) e o p-value for significante (menor que 0.05), a série é considerada estacionária. Do contrário a série é não estacionária

# %%
from statsmodels.tsa.stattools import adfuller   

result = adfuller(df['producao'].dropna()) 
print(f'Teste ADF:{result[0]}')
print(f'p-valor:{result[1]}')
print('Critical Values:')   

for key, value in result[4].items():
     print('\t%s: %.3f' % (key, value))
# Out:
# Teste ADF:-2.25699035004725
# p-valor:0.18621469116586592
# Critical Values:
# 	1%: -3.448
# 	5%: -2.869
# 	10%: -2.571

# %% [markdown]
# #### Ou seja, a série não é realmente estacionária (p-valor >0.05, não podemos rejeitar a hipótese nula)

# %%
import pandas.util.testing as tm
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib import pyplot

# %%
from pandas.plotting import autocorrelation_plot
# autocorrelation plot 
autocorrelation_plot(df)
pyplot.show()

# %%
plot_pacf(df, lags=80)
pyplot.show()

# %% [markdown]
# #### `Modelo ARIMA`
#
# Método estatístico que utiliza autoregressão e médias móveis para previsão de séries temporais. Um modelo linear é construído incluindo um número especificado de termos e os dados são preparados por um nível de diferenciação afim de tornar este estacionário.
#
# Podemos usar um valor 0 para desligar um parâmetro, dessa forma, aquela função em questão não será feita, por exemplo, se no parâmetro d definirmos 0 não será realizada uma diferenciação nos dados.

# %%
# ARIMA(p,d,q)
model = ARIMA(df, order=(7,1,1))

# %%
model_fit = model.fit()

# %%
# plot residuais
from pandas import DataFrame
residuals = DataFrame(model_fit.resid)

# %%
residuals.plot()
pyplot.show()

# %%
# gráficos de densidade dos residuais
residuals.plot(kind='kde')
pyplot.show()

# %%
# estatística descritiva dos residuos
print(residuals.describe())
# Out:
#                 0
# count  397.000000
# mean     0.401891
# std      5.275732
# min    -12.255685
# 25%     -2.074125
# 50%      0.103303
# 75%      2.400067
# max     72.505200

# %% [markdown]
# Prevendo dados com ARIMA utilizando Walk Forward
#
# O modelo arima contém alguns parâmetros
#
# ARIMA(p,d,q)
#     p: O número de lags que foram devem ser incluídos no modelo.
#     d: O número de vezes que as observações serão diferenciadas.
#     q: O tamanho de uma janela de média móvel. Também chamada de ordem de média móvel.

# %% [markdown]
# Separando dados treino e teste

# %%
# a variável X recebe os dados da série
X = df.values
X = X.astype('float32')

# %%
# Separa os dados com 50% dos dados para treino e 50% dos dados para teste
size = int(len(X) * 0.50)

# %%
# Separa dados de treino e teste
train = X[0:size]
test =  X[size:]

# %%
# cria a variável history, variavel de controle para o walk foward
history = [x for x in train]

# %%
# cria lista de previsões
predictions = list()

# %%
# Cria a função que faz a diferenciação - pega o valor do mes atual e subtrai com o mesmo mês do ano anterior, essa
# diferença vai ser o dataset diferenciado
def difference(dataset, interval=1):
  diff = list() 
  for i in range(interval, len(dataset)):
    value = dataset[i] - dataset[i - interval]
    diff.append(value)
  return diff

# cria função que reverte o valor diferenciado para o original
def inverse_difference(history, previsao, interval=1):
  return previsao + history[-interval]

# %%
# inicia Walk-Forward
for t in range(len(test)):
  
  # difference data
  meses_no_ano = 12
  diff = difference(history, meses_no_ano)
  
  # cria um modelo ARIMA com os dados de history p q e d
  model = ARIMA(diff, order=(1,0,1)) # p = vai usar o mes anterior como lag, d = medias movel nivel 1
  
  # treina o modelo ARIMA
  model_fit = model.fit()
  
  # a variável valor_predito recebe o valor previsto pelo modelo
  valor_predito = model_fit.forecast()[0]

  # valor_predito recebe o valor revertido (escala original)
  valor_predito = inverse_difference(history, valor_predito, meses_no_ano)
   
  # adiciona o valor predito na lista de predicões
  predictions.append(valor_predito)
  
  # a variável valor_real recebe o valor real do teste
  valor_real = test[t]
  
  # adiciona o valor real a variável history
  history.append(valor_real)

  # imprime valor predito e valor real
  print('Valor predito=%.3f, Valor esperado=%3.f' % (valor_predito, valor_real))
# Out:
# Valor predito=96.804, Valor esperado= 96
# Valor predito=100.436, Valor esperado=100
# Valor predito=91.995, Valor esperado= 88
# Valor predito=82.584, Valor esperado= 83
# Valor predito=88.926, Valor esperado= 83
# Valor predito=100.481, Valor esperado= 93
# Valor predito=104.419, Valor esperado=103
# Valor predito=94.581, Valor esperado= 95
# Valor predito=92.675, Valor esperado= 93
# Valor predito=84.036, Valor esperado= 86
# Valor predito=85.079, Valor esperado= 85
# Valor predito=92.654, Valor esperado= 93
# Valor predito=98.432, Valor esperado=102
# Valor predito=104.125, Valor esperado=102
# Valor predito=89.981, Valor esperado= 93
# Valor predito=86.439, Valor esperado= 87
# Valor predito=86.086, Valor esperado= 89
# Valor predito=97.116, Valor esperado=101
# Valor predito=108.378, Valor esperado=110
# Valor predito=100.226, Valor esperado=104
# Valor predito=99.298, Valor esperado= 95
# Valor predito=87.208, Valor esperado= 85
# Valor predito=85.550, Valor esperado= 85
# Valor predito=94.162, Valor esperado= 91
# Valor predito=101.852, Valor esperado=102
# Valor predito=102.368, Valor esperado=104
# Valor predito=95.860, Valor esperado= 93
# Valor predito=87.347, Valor esperado= 87
# Valor predito=89.126, Valor esperado= 89
# Valor predito=101.582, Valor esperado=104
# Valor predito=112.648, Valor esperado=114
# Valor predito=106.704, Valor esperado=106
# Valor predito=96.634, Valor esperado= 95
# Valor predito=86.283, Valor esperado= 87
# Valor predito=87.247, Valor esperado= 89
# Valor predito=94.003, Valor esperado= 96
# Valor predito=105.607, Valor esperado=102
# Valor predito=104.801, Valor esperado=100
# Valor predito=91.057, Valor esperado= 94
# Valor predito=88.316, Valor esperado= 88
# Valor predito=89.910, Valor esperado= 90
# Valor predito=104.937, Valor esperado=106
# Valor predito=115.823, Valor esperado=111
# Valor predito=105.239, Valor esperado=102
# Valor predito=93.614, Valor esperado= 99
# Valor predito=90.123, Valor esperado= 86
# Valor predito=89.475, Valor esperado= 87
# Valor predito=95.245, Valor esperado=100
# Valor predito=105.177, Valor esperado=108
# Valor predito=104.685, Valor esperado=109
# Valor predito=100.154, Valor esperado= 99
# Valor predito=90.772, Valor esperado= 90
# Valor predito=91.485, Valor esperado= 90
# Valor predito=106.939, Valor esperado=108
# Valor predito=113.524, Valor esperado=104
# Valor predito=98.285, Valor esperado=102
# Valor predito=100.045, Valor esperado= 98
# Valor predito=86.959, Valor esperado= 88
# Valor predito=88.666, Valor esperado= 90
# Valor predito=101.917, Valor esperado=101
# Valor predito=109.644, Valor esperado=111
# Valor predito=111.785, Valor esperado=112
# Valor predito=101.015, Valor esperado= 96
# Valor predito=88.532, Valor esperado= 90
# Valor predito=91.770, Valor esperado= 92
# Valor predito=110.104, Valor esperado=103
# Valor predito=102.245, Valor esperado=112
# Valor predito=106.254, Valor esperado=112
# Valor predito=104.632, Valor esperado= 99
# Valor predito=87.996, Valor esperado= 91
# Valor predito=92.755, Valor esperado= 92
# Valor predito=102.361, Valor esperado=101
# Valor predito=112.012, Valor esperado=108
# Valor predito=110.564, Valor esperado=114
# Valor predito=98.268, Valor esperado=102
# Valor predito=94.209, Valor esperado= 93
# Valor predito=94.265, Valor esperado= 94
# Valor predito=104.715, Valor esperado=107
# Valor predito=114.928, Valor esperado=115
# Valor predito=113.992, Valor esperado=108
# Valor predito=97.921, Valor esperado=100
# Valor predito=92.908, Valor esperado= 91
# Valor predito=92.953, Valor esperado= 91
# Valor predito=101.490, Valor esperado=104
# Valor predito=110.226, Valor esperado=111
# Valor predito=116.487, Valor esperado=108
# Valor predito=98.607, Valor esperado= 98
# Valor predito=92.920, Valor esperado= 91
# Valor predito=94.022, Valor esperado= 94
# Valor predito=107.806, Valor esperado=109
# Valor predito=117.217, Valor esperado=117
# Valor predito=109.960, Valor esperado=104
# Valor predito=99.089, Valor esperado= 98
# Valor predito=91.077, Valor esperado= 88
# Valor predito=90.788, Valor esperado= 88
# Valor predito=103.047, Valor esperado= 97
# Valor predito=108.110, Valor esperado=104
# Valor predito=104.929, Valor esperado=106
# Valor predito=97.978, Valor esperado= 95
# Valor predito=90.226, Valor esperado= 89
# Valor predito=93.739, Valor esperado= 89
# Valor predito=107.703, Valor esperado=111
# Valor predito=118.393, Valor esperado=119
# Valor predito=106.309, Valor esperado=111
# Valor predito=101.913, Valor esperado= 98
# Valor predito=88.997, Valor esperado= 86
# Valor predito=87.232, Valor esperado= 91
# Valor predito=99.909, Valor esperado=104
# Valor predito=108.448, Valor esperado=113
# Valor predito=111.140, Valor esperado=113
# Valor predito=99.218, Valor esperado=100
# Valor predito=92.687, Valor esperado= 89
# Valor predito=89.582, Valor esperado= 93
# Valor predito=113.471, Valor esperado=114
# Valor predito=121.650, Valor esperado=119
# Valor predito=111.365, Valor esperado=107
# Valor predito=97.228, Valor esperado= 99
# Valor predito=87.833, Valor esperado= 89
# Valor predito=93.284, Valor esperado= 90
# Valor predito=104.452, Valor esperado=103
# Valor predito=112.832, Valor esperado=115
# Valor predito=114.937, Valor esperado=114
# Valor predito=101.115, Valor esperado= 99
# Valor predito=89.311, Valor esperado= 90
# Valor predito=94.471, Valor esperado= 94
# Valor predito=115.566, Valor esperado=107
# Valor predito=116.110, Valor esperado=112
# Valor predito=104.499, Valor esperado=103
# Valor predito=98.150, Valor esperado= 94
# Valor predito=87.030, Valor esperado= 88
# Valor predito=90.150, Valor esperado= 93
# Valor predito=105.255, Valor esperado=101
# Valor predito=114.145, Valor esperado=113
# Valor predito=113.519, Valor esperado=110
# Valor predito=98.048, Valor esperado= 97
# Valor predito=89.709, Valor esperado= 90
# Valor predito=94.699, Valor esperado= 94
# Valor predito=108.294, Valor esperado=105
# Valor predito=111.358, Valor esperado=116
# Valor predito=106.315, Valor esperado=107
# Valor predito=95.927, Valor esperado=103
# Valor predito=93.587, Valor esperado= 91
# Valor predito=94.921, Valor esperado= 91
# Valor predito=100.587, Valor esperado=101
# Valor predito=113.660, Valor esperado=110
# Valor predito=108.854, Valor esperado=108
# Valor predito=96.653, Valor esperado= 99
# Valor predito=92.677, Valor esperado= 92
# Valor predito=95.622, Valor esperado= 97
# Valor predito=107.604, Valor esperado=113
# Valor predito=120.818, Valor esperado=124
# Valor predito=111.970, Valor esperado=113
# Valor predito=106.708, Valor esperado=105
# Valor predito=92.294, Valor esperado= 90
# Valor predito=91.135, Valor esperado= 92
# Valor predito=102.209, Valor esperado=102
# Valor predito=111.432, Valor esperado=109
# Valor predito=107.807, Valor esperado=108
# Valor predito=100.184, Valor esperado=100
# Valor predito=93.143, Valor esperado= 92
# Valor predito=98.232, Valor esperado=100
# Valor predito=115.598, Valor esperado=109
# Valor predito=122.239, Valor esperado=120
# Valor predito=111.629, Valor esperado=116
# Valor predito=107.989, Valor esperado=104
# Valor predito=90.361, Valor esperado= 90
# Valor predito=92.630, Valor esperado= 91
# Valor predito=101.984, Valor esperado=103
# Valor predito=109.812, Valor esperado=112
# Valor predito=110.638, Valor esperado=111
# Valor predito=102.227, Valor esperado=102
# Valor predito=93.775, Valor esperado= 92
# Valor predito=99.793, Valor esperado= 93
# Valor predito=106.113, Valor esperado=103
# Valor predito=117.965, Valor esperado=117
# Valor predito=115.658, Valor esperado=107
# Valor predito=99.351, Valor esperado= 95
# Valor predito=85.509, Valor esperado= 89
# Valor predito=92.340, Valor esperado= 91
# Valor predito=102.929, Valor esperado=104
# Valor predito=113.157, Valor esperado=115
# Valor predito=112.846, Valor esperado=116
# Valor predito=105.314, Valor esperado=103
# Valor predito=92.236, Valor esperado= 91
# Valor predito=93.602, Valor esperado= 93
# Valor predito=103.733, Valor esperado=113
# Valor predito=123.671, Valor esperado=115
# Valor predito=105.330, Valor esperado= 99
# Valor predito=92.145, Valor esperado=101
# Valor predito=94.530, Valor esperado= 88
# Valor predito=90.000, Valor esperado= 92
# Valor predito=105.642, Valor esperado=102
# Valor predito=114.002, Valor esperado=112
# Valor predito=114.953, Valor esperado=109
# Valor predito=99.772, Valor esperado= 99
# Valor predito=90.122, Valor esperado= 94
# Valor predito=94.997, Valor esperado= 97
# Valor predito=115.718, Valor esperado=115
# Valor predito=116.224, Valor esperado=129

# %%
# Avaliando os resultados
# calcula "a raiz quadrática média" dos erros entre valores observados (reais) e predições (hipóteses)
from numpy import sqrt
from sklearn.metrics import mean_squared_error
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 3.508

# %%
# plot forecasts against actual outcomes 
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()

# %% [markdown]
# #### `Analisando Resíduos`
#
#       Erro Residual = Valor esperado − Valor Predito
#
# - Erros residuais são erros em previsões de séries temporais.
# - Uma análise dos erros pode sugerir melhoras no modelo.
#   - Tendências.
#   - Sazonalidades.

# %%
# erros residuais 
residuals = [test[i] - predictions[i] for i in range(len(test))]

# %%
# converte a lista em um dataframe
residuals = pd.DataFrame(residuals)

# %%
# imprime as 5 primeiras linhas
residuals.head()
# Out:
#           0
# 0 -0.730423
# 1 -0.882477
# 2 -3.714371
# 3  0.101753
# 4 -5.994331

# %%
# estatística descritiva
residuals.describe()
# Out:
#                 0
# count  199.000000
# mean    -0.462702
# std      3.486058
# min     -9.051872
# 25%     -2.637535
# 50%     -0.552940
# 75%      1.711361
# max     13.180984

# %%
# plot residuals
residuals.plot()
pyplot.show()

# %%
# plots histograma
pyplot.figure()
pyplot.subplot(211)
residuals.hist(ax=pyplot.gca())

pyplot.subplot(212)
residuals.plot(kind='kde', ax=pyplot.gca())
pyplot.show()

# %%
# importa os pacotes de autocorrelação
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
# plots de autocorrelação
pyplot.figure() 
pyplot.subplot(211)
plot_acf(residuals, ax=pyplot.gca())
pyplot.subplot(212)
plot_pacf(residuals, ax=pyplot.gca())
pyplot.show()
